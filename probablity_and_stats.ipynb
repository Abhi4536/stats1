# %% [markdown]
# 1. What is a random variable in probability theory?
# A random variable is a function that assigns numerical values to outcomes of a random experiment. It helps quantify uncertainty in a mathematical way.
#
# 2. What are the types of random variables?
# Discrete Random Variable: Takes a countable number of values (e.g., number of heads in coin tosses).
#
# Continuous Random Variable: Takes an infinite number of values within a range (e.g., height, temperature).
#
# 3. What is the difference between discrete and continuous distributions?
# Discrete Distribution: Deals with countable outcomes (e.g., Binomial, Poisson).
#
# Continuous Distribution: Deals with measurable outcomes (e.g., Normal, Exponential).
#
# 4. What are probability distribution functions (PDF)?
# A Probability Distribution Function (PDF) describes the likelihood of different outcomes in a probability distribution. For continuous variables, it represents the probability density rather than an exact probability.
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# A CDF gives the probability that a random variable is less than or equal to a certain value, while a PDF gives the probability density at a specific point.
#
# 6. What is a discrete uniform distribution?
# A Discrete Uniform Distribution is one where all possible outcomes have equal probability. Example: Rolling a fair 6-sided die (each face has
# 1
# 6
# 6
# 1
# ​
#   probability).
#
# 7. What are the key properties of a Bernoulli distribution?
# Only two possible outcomes: Success (1) or Failure (0).
#
# Probability of success:
# 𝑝
# p.
#
# Probability of failure:
# 1
# −
# 𝑝
# 1−p.
#
# Mean:
# 𝑝
# p, Variance:
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p).
#
# 8. What is the binomial distribution, and how is it used in probability?
# A Binomial Distribution models the probability of exactly k successes in n independent Bernoulli trials, each with probability
# 𝑝
# p.
# Formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Example: Number of heads in 10 coin flips.
#
# 9. What is the Poisson distribution and where is it applied?
# A Poisson Distribution models the probability of a certain number of rare events occurring in a fixed interval of time or space.
# Formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# Example: Number of customer arrivals at a store per hour.
#
# 10. What is a continuous uniform distribution?
# A Continuous Uniform Distribution has constant probability density over a range
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b].
# PDF:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# ,
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#  ,a≤x≤b
# Example: Random number between 0 and 1.
#
# 11. What are the characteristics of a normal distribution?
# Bell-shaped curve
#
# Symmetric around the mean
# 𝜇
# μ
#
# Defined by mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ
#
# 68-95-99.7 rule (Empirical Rule)
#
# 12. What is the standard normal distribution, and why is it important?
# A Standard Normal Distribution is a normal distribution with:
#
# Mean
# 𝜇
# =
# 0
# μ=0
#
# Standard deviation
# 𝜎
# =
# 1
# σ=1
# It allows for easy comparison of different datasets using Z-scores.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the population distribution.
# It is crucial because it allows normal approximation in inferential statistics.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
# Even if the original data is not normally distributed, the distribution of the sample mean will be approximately normal if the sample size is large enough (
# 𝑛
# ≥
# 30
# n≥30).
#
# 15. What is the application of Z statistics in hypothesis testing?
# Z-statistics are used in hypothesis tests when:
#
# The population variance is known.
#
# The sample size is large.
# It helps determine if the observed sample mean significantly differs from a hypothesized mean.
#
# 16. How do you calculate a Z-score, and what does it represent?
# Z-score formula:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# It measures how many standard deviations a data point is from the mean.
#
# 17. What are point estimates and interval estimates in statistics?
# Point Estimate: A single value estimate of a population parameter (e.g., sample mean for population mean).
#
# Interval Estimate: A range of values within which the population parameter is likely to fall (e.g., confidence intervals).
#
# 18. What is the significance of confidence intervals in statistical analysis?
# A confidence interval (CI) provides a range of values that likely contain the true population parameter with a certain probability (e.g., 95% confidence interval).
#
# 19. What is the relationship between a Z-score and a confidence interval?
# Z-scores determine the margin of error for a confidence interval:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑍
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±Z
# n
# ​
#
# σ
# ​
#
# Where
# 𝑍
# Z corresponds to the confidence level (e.g., 1.96 for 95%).
#
# 20. How are Z-scores used to compare different distributions?
# Z-scores standardize values, allowing comparisons across different distributions by converting data to a common scale (standard normal distribution).
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# Random sampling
#
# Independent observations
#
# Sample size
# 𝑛
# ≥
# 30
# n≥30 or population is normal
#
# Finite variance
#
# 22. What is the concept of expected value in a probability distribution?
# The expected value (mean) of a random variable represents the long-term average outcome:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑥
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# (discrete)
# E(X)=∑xP(X=x)(discrete)
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# 𝑥
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# (continuous)
# E(X)=∫xf(x)dx(continuous)
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# The probability distribution determines the expected value, which represents the average outcome over many trials.
